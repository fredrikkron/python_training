# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("data/athlete_events.csv")
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
list(df.columns)
# Out:
# ['ID',
#  'Name',
#  'Sex',
#  'Age',
#  'Height',
#  'Weight',
#  'Team',
#  'NOC',
#  'Games',
#  'Year',
#  'Season',
#  'City',
#  'Sport',
#  'Event',
#  'Medal']

# %%
df2 = df.copy()

# %%
df2.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
count_male_athletes = df2[["Sex", "Year", "Sport"]].value_counts().xs('M', level='Sex')
count_male_athletes
# Out:
# Year  Sport
# 1996  Athletics        1490
# 1952  Gymnastics       1465
# 2000  Athletics        1437
# 1988  Athletics        1324
# 2016  Athletics        1300
#                        ...
# 1904  Roque               4
# 1932  Alpinism            2
# 1900  Basque Pelota       2
# 1936  Alpinism            1
#       Aeronautics         1
# Name: count, Length: 884, dtype: int64

# %%
df2[df.index.isin(range(1130,1140))]
# Out:
#        ID            Name Sex   Age  Height  Weight         Team  NOC  \
# 1130  633  Martina Accola   F  24.0   170.0    62.0  Switzerland  SUI
# 1131  633  Martina Accola   F  28.0   170.0    62.0  Switzerland  SUI
# 1132  634     Paul Accola   M  20.0   176.0    82.0  Switzerland  SUI
# 1133  634     Paul Accola   M  20.0   176.0    82.0  Switzerland  SUI
# 1134  634     Paul Accola   M  24.0   176.0    82.0  Switzerland  SUI
# 1135  634     Paul Accola   M  24.0   176.0    82.0  Switzerland  SUI
# 1136  634     Paul Accola   M  24.0   176.0    82.0  Switzerland  SUI
# 1137  634     Paul Accola   M  24.0   176.0    82.0  Switzerland  SUI
# 1138  634     Paul Accola   M  24.0   176.0    82.0  Switzerland  SUI
# 1139  634     Paul Accola   M  26.0   176.0    82.0  Switzerland  SUI
#
#             Games  Year  Season         City          Sport  \
# 1130  1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 1131  1998 Winter  1998  Winter       Nagano  Alpine Skiing
# ...

# %%
df2.index = range(1,271117)
df2
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 1            1                 A Dijiang   M  24.0   180.0    80.0
# 2            2                  A Lamusi   M  23.0   170.0    60.0
# 3            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 4            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271112  135569                Andrzej ya   M  29.0   179.0    89.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135570                  Piotr ya   M  27.0   176.0    59.0
# 271115  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271116  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 1                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df2.loc[1]
# Out:
# ID                                  1
# Name                        A Dijiang
# Sex                                 M
# Age                              24.0
# Height                          180.0
# Weight                           80.0
# Team                            China
# NOC                               CHN
# Games                     1992 Summer
# Year                             1992
# Season                         Summer
# City                        Barcelona
# Sport                      Basketball
# Event     Basketball Men's Basketball
# Medal                             NaN
# Name: 1, dtype: object

# %%
df2.iloc[1,7]
# Out:
# 'CHN'

# %%
df2.loc[10:14]
# Out:
#     ID                      Name Sex   Age  Height  Weight           Team  \
# 10   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0    Netherlands
# 11   6           Per Knut Aaland   M  31.0   188.0    75.0  United States
# 12   6           Per Knut Aaland   M  31.0   188.0    75.0  United States
# 13   6           Per Knut Aaland   M  31.0   188.0    75.0  United States
# 14   6           Per Knut Aaland   M  31.0   188.0    75.0  United States
#
#     NOC        Games  Year  Season         City                 Sport  \
# 10  NED  1994 Winter  1994  Winter  Lillehammer         Speed Skating
# 11  USA  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 12  USA  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 13  USA  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 14  USA  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
#
#                                                 Event Medal
# ...

# %%
df2.iloc[10:14]
# Out:
#     ID             Name Sex   Age  Height  Weight           Team  NOC  \
# 11   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 12   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 13   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 14   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
#
#           Games  Year  Season         City                 Sport  \
# 11  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 12  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 13  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 14  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
#
#                                                 Event Medal
# 11           Cross Country Skiing Men's 10 kilometres   NaN
# 12           Cross Country Skiing Men's 50 kilometres   NaN
# 13  Cross Country Skiing Men's 10/15 kilometres Pu...   NaN
# ...

# %%
df.loc[[103,180,333]]
# Out:
#       ID                     Name Sex   Age  Height  Weight  \
# 103   36     Stefan Remco Aartsen   M  25.0   194.0    78.0
# 180   78             Salim Abanoz   M  26.0     NaN     NaN
# 333  183  Abdel Sattar Abdel Hadj   M   NaN     NaN     NaN
#
#                      Team  NOC        Games  Year  Season     City     Sport  \
# 103           Netherlands  NED  2000 Summer  2000  Summer   Sydney  Swimming
# 180                Turkey  TUR  1996 Summer  1996  Summer  Atlanta      Judo
# 333  United Arab Republic  UAR  1960 Summer  1960  Summer     Roma    Rowing
#
#                                    Event Medal
# 103  Swimming Men's 100 metres Butterfly   NaN
# 180               Judo Men's Lightweight   NaN
# 333            Rowing Men's Coxed Eights   NaN

# %%
df2.loc[100:108, ['Name', "Team", 'Sport']]
# Out:
#                        Name         Team       Sport
# 100  Dagfinn Sverre Aarskog       Norway   Bobsleigh
# 101    Stefan Remco Aartsen  Netherlands    Swimming
# 102    Stefan Remco Aartsen  Netherlands    Swimming
# 103    Stefan Remco Aartsen  Netherlands    Swimming
# 104    Stefan Remco Aartsen  Netherlands    Swimming
# 105    Stefan Remco Aartsen  Netherlands    Swimming
# 106      Ann Kristin Aarnes       Norway    Football
# 107            Karl Jan Aas       Norway  Gymnastics
# 108      Lars Thorlaksn Aas       Norway     Fencing

# %%
df2[df2.Age > 60].value_counts("Name").head(10)
# Out:
# Name
# Robert Tait McKenzie                    50
# Alfred James Munnings                   25
# Stanisaw Noakowski                      17
# Anne Marie Carl-Nielsen (Brodersen-)    13
# Konstantns Visotskis                    12
# Frank Weston Benson                     12
# Laura Knight (Johnson-)                 10
# George Denholm Armour                    7
# Lisa "Louise" Bianchini (Wadstrm-)       7
# Oscar Gomer Swahn                        7
# Name: count, dtype: int64

# %%
df2[df2.Age > 90]
# Out:
#             ID                    Name Sex   Age  Height  Weight  \
# 98119    49663           Winslow Homer   M  96.0     NaN     NaN
# 257055  128719  John Quincy Adams Ward   M  97.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season         City  \
# 98119   United States  USA  1932 Summer  1932  Summer  Los Angeles
# 257055  United States  USA  1928 Summer  1928  Summer    Amsterdam
#
#                    Sport                                           Event Medal
# 98119   Art Competitions  Art Competitions Mixed Painting, Unknown Event   NaN
# 257055  Art Competitions     Art Competitions Mixed Sculpturing, Statues   NaN

# %%
df2.replace({96:99}, inplace=True)
df2[df2.Age > 90]
# Out:
#             ID                    Name Sex   Age  Height  Weight  \
# 98119    49663           Winslow Homer   M  99.0     NaN     NaN
# 257055  128719  John Quincy Adams Ward   M  97.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season         City  \
# 98119   United States  USA  1932 Summer  1932  Summer  Los Angeles
# 257055  United States  USA  1928 Summer  1928  Summer    Amsterdam
#
#                    Sport                                           Event Medal
# 98119   Art Competitions  Art Competitions Mixed Painting, Unknown Event   NaN
# 257055  Art Competitions     Art Competitions Mixed Sculpturing, Statues   NaN

# %%
df2[df2.Age == 82].head()
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
df2.loc[df2['Age'] == 76, 'Age'] = 82
df3 = df2[df2.Age == 82].head()
df3
# Out:
#            ID                  Name Sex   Age  Height  Weight           Team  \
# 56600   28993          Albin Dbrich   M  82.0     NaN     NaN        Austria
# 56601   28993          Albin Dbrich   M  82.0     NaN     NaN        Austria
# 56602   28993          Albin Dbrich   M  82.0     NaN     NaN        Austria
# 62840   32215  George Alfred Elcock   M  82.0     NaN     NaN  Great Britain
# 133534  67219       Sir John Lavery   M  82.0     NaN     NaN  Great Britain
#
#         NOC        Games  Year  Season         City             Sport  \
# 56600   AUT  1948 Summer  1948  Summer       London  Art Competitions
# 56601   AUT  1948 Summer  1948  Summer       London  Art Competitions
# 56602   AUT  1948 Summer  1948  Summer       London  Art Competitions
# 62840   GBR  1932 Summer  1932  Summer  Los Angeles  Art Competitions
# 133534  GBR  1932 Summer  1932  Summer  Los Angeles  Art Competitions
#
#                                                     Event Medal
# ...

# %%
df2[df2.Age == 76].head()
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
import openpyxl
df3.to_excel('my_excel.xlsx', index=False)

# %%
df4 = df3.loc[:, ['Name', 'Age', 'Sex', 'Team', 'Year']]
df4
# Out:
#                         Name   Age Sex           Team  Year
# 56600           Albin Dbrich  82.0   M        Austria  1948
# 56601           Albin Dbrich  82.0   M        Austria  1948
# 56602           Albin Dbrich  82.0   M        Austria  1948
# 62840   George Alfred Elcock  82.0   M  Great Britain  1932
# 133534       Sir John Lavery  82.0   M  Great Britain  1932

# %%
df4.to_csv('my_csv.csv', index=False)
